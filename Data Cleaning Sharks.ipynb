# %%
import numpy as np
import pandas as pd
import re

from scipy import stats
from datetime import datetime

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.- Data Exploration

# %%
data = pd.read_csv('Shark_attacks_clean.csv')
data.head(2)
# Out:
#          Date        Type Country     Area                          Location  \
# 0  2016-09-18  Unprovoked     USA  Florida  New Smyrna Beach, Volusia County
# 1  2016-09-18  Unprovoked     USA  Florida  New Smyrna Beach, Volusia County
#
#   Activity_during_attack Victim_Name Gender   Age                    Injury  \
# 0                Surfing        male      M  16.0     Minor injury to thigh
# 1                Surfing        male      M  43.0  Lacerations to lower leg
#
#    Fatal_attack Shark_species           Source_information  \
# 0         False  Unidentified  Orlando Sentinel, 9/19/2016
# 1         False  Unidentified  Orlando Sentinel, 9/19/2016
#
#       Documentation_pdf                                 Documentation_href
# 0  2016.09.18.c-NSB.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  2016.09.18.a-NSB.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5807 entries, 0 to 5806
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    5807 non-null   object
#  1   Type                    5807 non-null   object
#  2   Country                 5807 non-null   object
#  3   Area                    5807 non-null   object
#  4   Location                5693 non-null   object
#  5   Activity_during_attack  5448 non-null   object
#  6   Victim_Name             5807 non-null   object
#  7   Gender                  5269 non-null   object
#  8   Age                     5126 non-null   float64
#  9   Injury                  5807 non-null   object
#  10  Fatal_attack            5807 non-null   bool
#  11  Shark_species           5807 non-null   object
#  12  Source_information      5807 non-null   object
#  13  Documentation_pdf       5807 non-null   object
#  14  Documentation_href      5807 non-null   object
# dtypes: bool(1), float64(1), object(13)
# memory usage: 640.9+ KB

# %% [markdown]
# 1) There are no columns 22 & 23 to be removed

# %% [markdown]
# 2) Columns to change type:
#     0-Date to datestamp
#     8-Age to int64

# %% [markdown]
# 3) Check duplicated rows

# %%
(data[[column for column in list(data.columns)]][data[[column for column in list(data.columns)]].duplicated()])
# Out:
#             Date      Type Country        Area               Location  \
# 5096  1923-01-01  Provoked     USA  New Jersey  Ocean City (offshore)
#
#      Activity_during_attack Victim_Name Gender  Age  \
# 5096               Hoisting        male      M  NaN
#
#                                              Injury  Fatal_attack  \
# 5096  Shark's tail broke his leg. PROVOKED INCIDENT         False
#
#      Shark_species                                 Source_information  \
# 5096  Unidentified  Ref in New York Herald Tribune, 8/23/1960; V.M...
#
#                   Documentation_pdf  \
# 5096  1923.00.00.a-NJ fisherman.pdf
#
#                                      Documentation_href
# 5096  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# 4) Only row 5096 appears to be twice in the dataset, if so, we can drop the row by filtering location

# %%
data[data.loc[:,'Location'] == 'Ocean City (offshore)']
# Out:
#             Date      Type Country        Area               Location  \
# 5095  1923-01-01  Provoked     USA  New Jersey  Ocean City (offshore)
# 5096  1923-01-01  Provoked     USA  New Jersey  Ocean City (offshore)
#
#      Activity_during_attack Victim_Name Gender  Age  \
# 5095               Hoisting        male      M  NaN
# 5096               Hoisting        male      M  NaN
#
#                                              Injury  Fatal_attack  \
# 5095  Shark's tail broke his leg. PROVOKED INCIDENT         False
# 5096  Shark's tail broke his leg. PROVOKED INCIDENT         False
#
#      Shark_species                                 Source_information  \
# 5095  Unidentified  Ref in New York Herald Tribune, 8/23/1960; V.M...
# 5096  Unidentified  Ref in New York Herald Tribune, 8/23/1960; V.M...
#
#                   Documentation_pdf  \
# 5095  1923.00.00.a-NJ fisherman.pdf
# 5096  1923.00.00.a-NJ fisherman.pdf
#
#                                      Documentation_href
# 5095  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5096  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
data = data.drop(5095, axis=0)

# %%
# Just verifying the row has been succesfully dropped
data[data.loc[:,'Location'] == 'Ocean City (offshore)']
# Out:
#             Date      Type Country        Area               Location  \
# 5096  1923-01-01  Provoked     USA  New Jersey  Ocean City (offshore)
#
#      Activity_during_attack Victim_Name Gender  Age  \
# 5096               Hoisting        male      M  NaN
#
#                                              Injury  Fatal_attack  \
# 5096  Shark's tail broke his leg. PROVOKED INCIDENT         False
#
#      Shark_species                                 Source_information  \
# 5096  Unidentified  Ref in New York Herald Tribune, 8/23/1960; V.M...
#
#                   Documentation_pdf  \
# 5096  1923.00.00.a-NJ fisherman.pdf
#
#                                      Documentation_href
# 5096  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# 5) Now check how many null data is in dataset

# %%
# checar valores nulos en columnas
null_cols = data.isnull().sum()
null_cols
# Out:
# Date                        0
# Type                        0
# Country                     0
# Area                        0
# Location                  114
# Activity_during_attack    359
# Victim_Name                 0
# Gender                    538
# Age                       680
# Injury                      0
# Fatal_attack                0
# Shark_species               0
# Source_information          0
# Documentation_pdf           0
# Documentation_href          0
# dtype: int64

# %%
# only 4 columns with null data
null_cols[null_cols > 0]
# Out:
# Location                  114
# Activity_during_attack    359
# Gender                    538
# Age                       680
# dtype: int64

# %%
# turning nulls into percetage 
null_cols = data.isnull().mean()
null_cols = null_cols[null_cols > 0].sort_values() * 100
null_cols
# Out:
# Location                   1.963486
# Activity_during_attack     6.183259
# Gender                     9.266276
# Age                       11.712022
# dtype: float64

# %% [markdown]
# 6) "Due to the relevance of the "Species" column in the data set, we cannot drop this column, even when the percentage of NaN's there is near to 50%."
#
# But 'Species' has no null data, most of them are 'Unidentified'

# %% [markdown]
# 7) "The column "Time" and "Year" seems to be irrelevant. However we will explore it further"
#
# There are no columns 'Time' or 'Year' but maybe it will be necesary to obtain year after cleaning 'Date' column

# %% [markdown]
# 8) "The columns "Country", "Area" and "Location" are related, so it might be possible to infer the missing values one from the others"
#
# Lets check it

# %%
# Checking nulls in 'Location'
data[(data.Country.isna() == False) & (data.Area.isna()== False) & (data.Location.isna())].head(2)
# Out:
#           Date        Type     Country              Area Location  \
# 54  2016-06-24  Unprovoked    COLOMBIA  Isla Provedencia      NaN
# 86  2016-04-08     Invalid  CAPE VERDE  Boa Vista Island      NaN
#
#    Activity_during_attack        Victim_Name Gender   Age  \
# 54                 Diving       Arturo Velez      M  59.0
# 86               Swimming  a British citizen      M  60.0
#
#                        Injury  Fatal_attack                    Shark_species  \
# 54  Severe bite to right hand         False       Caribbean reef shark, 4.5'
# 86                  "Serious"         False  Shark involvement not confirmed
#
#    Source_information         Documentation_pdf  \
# 54       Dr. A. Velez      2016.06.24-Velez.pdf
# 86         L.O.Guttke  2016.04.08-CapeVerde.pdf
#
#                                    Documentation_href
# 54  http://sharkattackfile.net/spreadsheets/pdf_di...
# 86  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# list of the rows indexes for null values in 'Location' column
null_rows = list(data[(data.Country.isna() == False) & (data.Area.isna()== False) & (data.Location.isna())].index)
# list of the areas for null values in 'Location' column
areas = list(data[((data.Country.isna() == False) & (data.Area.isna() == False) & (data.Location.isna()))]["Area"].loc[null_rows])

# 'for loop' to check if we can fill null values in 'Location' by areas
b = []
for i in range(0,len(areas)):
    a = data[data.loc[:,'Area'] == areas[i]]
    indexes = len(a)
    # this 'if' filters 'a' when area is in more than 1 index in original 'data'
    if indexes > 1:
        b.append(a)
# dataframe with repeated areas
b = pd.concat(b, axis=0)

# %%
b.head(2)
# Out:
#            Date        Type Country           Area Location  \
# 350  2014-06-01  Unprovoked     USA  Palmyra Atoll      NaN
# 800  2010-11-19    Provoked     USA  Palmyra Atoll      NaN
#
#     Activity_during_attack   Victim_Name Gender   Age  \
# 350                Tagging        female      F  37.0
# 800             Snorkeling  Kydd Pollock      M  33.0
#
#                                             Injury  Fatal_attack  \
# 350                        Laceration to left hand         False
# 800  Head bitten by netted shark PROVOKED INCIDENT         False
#
#             Shark_species       Source_information  \
# 350  Blacktip Reef shark          U.S. Coast Guard
# 800          Unidentified  Sunday News, 12/12/2010
#
#                  Documentation_pdf  \
# 350  2014.06.01.a-PalmyraAtoll.pdf
# 800         2010.11.19-Pollock.pdf
#
#                                     Documentation_href
# 350  http://sharkattackfile.net/spreadsheets/pdf_di...
# 800  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# 9) Unfortunatelly we cannot infer locations by repeating areas.
# We will leave these rows by now and see if we can drop this null values later

# %% [markdown]
# 10) Capitalizing 'Country' column

# %%
data["Country"] = data['Country'].str.capitalize()

# %%
data.head(2)
# Out:
#          Date        Type Country     Area                          Location  \
# 0  2016-09-18  Unprovoked     Usa  Florida  New Smyrna Beach, Volusia County
# 1  2016-09-18  Unprovoked     Usa  Florida  New Smyrna Beach, Volusia County
#
#   Activity_during_attack Victim_Name Gender   Age                    Injury  \
# 0                Surfing        male      M  16.0     Minor injury to thigh
# 1                Surfing        male      M  43.0  Lacerations to lower leg
#
#    Fatal_attack Shark_species           Source_information  \
# 0         False  Unidentified  Orlando Sentinel, 9/19/2016
# 1         False  Unidentified  Orlando Sentinel, 9/19/2016
#
#       Documentation_pdf                                 Documentation_href
# 0  2016.09.18.c-NSB.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  2016.09.18.a-NSB.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# 11) 'Cleaning and parsing the column "Date"'
#
# 'Date' column appears to be ok overall. No cleaning needed

# %% [markdown]
# 12) 'Droping the column "Case Number", "Year" and "original order"'
#
# "Case Number", "Year" and "original order" columns are not in dataset.

# %% [markdown]
# 13) 'Filling values for "Name" and "Investigator or Source"'
#
# We check if 'Name' can be infered by other columns

# %%
data['Victim_Name'].unique()
# Out:
# array(['male', 'Chucky Luciano', 'Rory Angiolella', ...,
#        'Samuel Jennings, a deserter from the British frigate Milford',
#        'seaman', 'seaman from the York'], dtype=object)

# %% [markdown]
# 14) We 'could' fill the names by searching patterns in the 'Documentation-href' column, but this would take a lot of time due to the many different text entries in 'Victim_Name' column.
# Therefore, we will leave 'Victim_Name' as it is.
# 'Source' column needs no filling either.

# %% [markdown]
# 15) Tiding column "Activity" by extracting verbs in gerund.

# %%
# obtaining list with rows in which no age nor activity have data,
# We will delete this rows from the dataset since they will not work with the predictor function
data_temp = list(data[(data['Activity_during_attack'].isnull()== True) & (data['Age'].isnull()== True)].index)
data = data.drop(data_temp, axis=0)

# %%
# this list will contain all activities, even those with long texts
activity_list = list(data['Activity_during_attack'].unique())
# regex pattern for gerund verbs
pattern = r'\b(\w+ing)\b'
gerund_verbs_list = []

# this for loop will deliver only the -ing gerung verbs
for i in range(0,len(activity_list)):
    x = re.findall(r'\b(\w+ing)\b', str(activity_list[i]))
    gerund_verbs_list.append(x)
    
# this for loop deliveres the last list but clean
gerund_verbs_list_clean = []
for i in gerund_verbs_list:
    for j in i:
        gerund_verbs_list_clean.append(j)

# %%
# we will use the last 'gerund_verbs_list_clean' list to filter 
# and eliminate activities with no useful data for the preductor function
data = data.loc[data['Activity_during_attack'].isin(gerund_verbs_list_clean)]
data.head(2)
# Out:
#          Date        Type Country     Area                          Location  \
# 0  2016-09-18  Unprovoked     Usa  Florida  New Smyrna Beach, Volusia County
# 1  2016-09-18  Unprovoked     Usa  Florida  New Smyrna Beach, Volusia County
#
#   Activity_during_attack Victim_Name Gender   Age                    Injury  \
# 0                Surfing        male      M  16.0     Minor injury to thigh
# 1                Surfing        male      M  43.0  Lacerations to lower leg
#
#    Fatal_attack Shark_species           Source_information  \
# 0         False  Unidentified  Orlando Sentinel, 9/19/2016
# 1         False  Unidentified  Orlando Sentinel, 9/19/2016
#
#       Documentation_pdf                                 Documentation_href
# 0  2016.09.18.c-NSB.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  2016.09.18.a-NSB.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# checking nulls percentage drop
null_cols = data.isnull().mean()
null_cols = null_cols[null_cols > 0].sort_values() * 100
null_cols
# Out:
# Location    1.411488
# Age         1.901588
# Gender      6.567340
# dtype: float64

# %% [markdown]
# 16) Create a Predictor Function and with it, filling NaN values in Columns "Age" and "Activity".
# For this function we need a frequency list, a dataframe filter based in the frequency list

# %%
# replacing nulls in 'Age' to zeros
data['Age'] = data['Age'].fillna(0)
# Changing 'Age' from float64 to int64
data['Age'] = data['Age'].astype(np.int64)

# %%
# frequency list, first for 'Age'
age_frequency = list(data['Age'].value_counts().index)
# dataframe filter, this will create a list with count - age
data_filter = data[data['Age'].isin(age_frequency)]['Age'].value_counts()
most_frequent = list(data_filter.index)[0]

# %%
# in the dataset, 18 years is the most frequent age and fishing the most common activity
x = (most_frequent, data[(data['Age'].isin(age_frequency)) 
                         & (data['Age'] == most_frequent)]['Activity_during_attack'].value_counts())
x
# Out:
# (18,
#  Fishing         476
#  Surfing          43
#  Swimming         31
#  Floating         16
#  Treading          9
#  Boarding          7
#  Diving            7
#  Spearfishing      6
#  Wading            5
#  Bathing           4
#  Standing          4
#  Filming           2
#  Snorkeling        2
#  Walking           1
#  Playing           1
#  Scurfing          1
#  Splashing         1
#  Paddling          1
#  Jumping           1
#  Holding           1
#  Name: Activity_during_attack, dtype: int64)

# %%
# this function will search through all the most common ages by activity
def predictor(column1, column2, dataframe):
    age_frequency = list(dataframe[column1].value_counts().index)
    data_filter = dataframe[dataframe[column1].isin(age_frequency)][column2].value_counts()
    a = {}
    for i in list(data_filter.index):
        a[i] = dataframe[dataframe[column1].isin(age_frequency)][column1].value_counts().index[0]
    return a

# %%
predictor('Age', 'Activity_during_attack', data)
# Out:
# {'Surfing': 18,
#  'Swimming': 18,
#  'Fishing': 18,
#  'Diving': 18,
#  'Spearfishing': 18,
#  'Bathing': 18,
#  'Wading': 18,
#  'Boarding': 18,
#  'Standing': 18,
#  'Snorkeling': 18,
#  'Floating': 18,
#  'Treading': 18,
#  'Kayaking': 18,
#  'Skiing': 18,
#  'Attempting': 18,
#  'Walking': 18,
#  'Playing': 18,
#  'Sitting': 18,
#  'Windsurfing': 18,
#  'Rowing': 18,
#  'Paddling': 18,
#  'Sinking': 18,
#  'Canoeing': 18,
#  'Sailing': 18,
#  'Freediving': 18,
#  'Collecting': 18,
#  'Skindiving': 18,
#  'Washing': 18,
#  'Netting': 18,
#  'Splashing': 18,
#  'During': 18,
#  'Jumping': 18,
#  'Boating': 18,
#  'Feeding': 18,
#  'Hunting': 18,
#  'Lying': 18,
#  'Clinging': 18,
#  'Removing': 18,
#  'Filming': 18,
#  'Watching': 18,
#  'Competing': 18,
#  'Crossing': 18,
#  'Lifesaving': 18,
#  'Tagging': 18,
#  'Dangling': 18,
#  'Paddleskiing': 18,
#  'Clamming': 18,
#  'Paddleboarding': 18,
#  'Returning': 18,
#  'Being': 18,
#  'Riding': 18,
#  'Crabbing': 18,
#  'Catching': 18,
#  'Pulling': 18,
#  'Spearing': 18,
#  'Cleaning': 18,
#  'Escaping': 18,
#  'Dragging': 18,
#  'Sculling': 18,
#  'Finning': 18,
#  'Flying': 18,
#  'Working': 18,
#  'Retrieving': 18,
#  'Carrying': 18,
#  'Photographing': 18,
#  'Racing': 18,
#  'Testing': 18,
#  'Launching': 18,
#  'Helping': 18,
#  'Picking': 18,
#  'Preparing': 18,
#  'Killing': 18,
#  'Gathering': 18,
#  'Crayfishing': 18,
#  'Hauling': 18,
#  'Holding': 18,
#  'Boeing': 18,
#  'Landing': 18,
#  'Petting': 18,
#  'Conducting': 18,
#  'Gaffing': 18,
#  'Abandoning': 18,
#  'Climbing': 18,
#  'Foundering': 18,
#  'Touching': 18,
#  'Taking': 18,
#  'Shooting': 18,
#  'Rescuing': 18,
#  'Teasing': 18,
#  'Crouching': 18,
#  'Kiteboarding': 18,
#  'Chumming': 18,
#  'Cruising': 18,
#  'Moving': 18,
#  'Towing': 18,
#  'Wearing': 18,
#  'Hanging': 18,
#  'Trailing': 18,
#  'Resting': 18,
#  'Trying': 18,
#  'Painting': 18,
#  'Coming': 18,
#  'Examining': 18,
#  'Bending': 18,
#  'Defecating': 18,
#  'Involving': 18,
#  'Fighting': 18,
#  'Traveling': 18,
#  'Bringing': 18,
#  'Cutting': 18,
#  'Angling': 18,
#  'Guarding': 18,
#  'Dismantling': 18,
#  'Longling': 18,
#  'Pursuing': 18,
#  'Harpooning': 18,
#  'Expecting': 18,
#  'Deserting': 18,
#  'Pearling': 18,
#  'Hooking': 18,
#  'Stuffing': 18,
#  'Hoisting': 18,
#  'Shelling': 18,
#  'Restraining': 18,
#  'Drowning': 18,
#  'Feeling': 18,
#  'Oystering': 18,
#  'Awaiting': 18,
#  'Scooping': 18,
#  'Waiting': 18,
#  'Yachting': 18,
#  'Travelling': 18,
#  'Harassing': 18,
#  'Burning': 18,
#  'Sittting': 18,
#  'Lashing': 18,
#  'Crawling': 18,
#  'Dropping': 18,
#  'Observing': 18,
#  'Stamding': 18,
#  'Sleeping': 18,
#  'Hiking': 18,
#  'Scurfing': 18,
#  'Shrimping': 18,
#  'Reviving': 18,
#  'Measuring': 18,
#  'Dynamiting': 18,
#  'Wakeboarding': 18,
#  'Bodyboarding': 18,
#  'Wrangling': 18,
#  'Casting': 18,
#  'Kitesurfing': 18,
#  'Kneeling': 18,
#  'Bodysurfing': 18,
#  'Lobstering': 18,
#  'Ditching': 18,
#  'Meshing': 18,
#  'Investigating': 18,
#  'Sailboarding': 18,
#  'Setting': 18,
#  'Lining': 18,
#  'Chasing': 18,
#  'Checking': 18,
#  'Attaching': 18,
#  'Missing': 18,
#  'Seining': 18,
#  'Searching': 18,
#  'Sunbathing': 18,
#  'Throwing': 18,
#  'Leaving': 18,
#  'Seeing': 18,
#  'Thrashing': 18,
#  'Drawing': 18,
#  'Exercising': 18,
#  'Morning': 18,
#  'Inspecting': 18,
#  'Loading': 18}

# %% [markdown]
# 17) Based on the results of the last output, we can substitute all the '0' in 'Age' column for '18'

# %%
data['Age'] = data['Age'].replace(0,18)

# %%
# verifying there are no more '0' in 'Age'
data[data.loc[:,'Age'] == 0]
# Out:
# Empty DataFrame
# Columns: [Date, Type, Country, Area, Location, Activity_during_attack, Victim_Name, Gender, Age, Injury, Fatal_attack, Shark_species, Source_information, Documentation_pdf, Documentation_href]
# Index: []

# %%
data['Age'].unique()
# Out:
# array([16, 43, 36, 17, 18, 65, 51, 50, 12,  9, 22, 37, 25, 20, 49, 15, 21,
#        40, 72, 27, 29, 28, 31, 11, 30, 24, 10, 59, 42, 34, 35, 26, 13, 19,
#         6, 60, 64, 23, 52, 57, 48, 39, 69, 46, 41, 45, 38, 71, 32, 55, 54,
#        44, 14,  7, 62, 68, 47, 63, 70, 58,  1, 53, 33,  8, 61, 66, 77, 74,
#         3, 56,  5, 86, 84, 75, 73, 87, 67, 81, 78], dtype=int64)

# %%
# checking nulls percentage drop
null_cols = data.isnull().mean()
null_cols = null_cols[null_cols > 0].sort_values() * 100
null_cols
# Out:
# Location    1.411488
# Gender      6.567340
# dtype: float64

# %% [markdown]
# 18) Location cannot be inferred with other columns, we could drop these values, but since is more than 1% we will let them and fill the nulls with 'Unknown
# Gender could be inferred with the names in 'Victim_Name', although we will fill nulls with 'Unknown' since the nulls are considerably more than 5% of the toal entries

# %%
data['Location'] = data['Location'].fillna('Unknown')
data['Gender'] = data['Gender'].fillna('Unknown')

# %%
# checking nulls percentage drop
null_cols = data.isnull().mean()
null_cols = null_cols[null_cols > 0].sort_values() * 100
null_cols
# Out:
# Series([], dtype: float64)

# %%
# reseting index
data.reset_index(drop=True)
# Out:
#             Date        Type    Country               Area  \
# 0     2016-09-18  Unprovoked        Usa            Florida
# 1     2016-09-18  Unprovoked        Usa            Florida
# 2     2016-09-18  Unprovoked        Usa            Florida
# 3     2016-09-17  Unprovoked  Australia           Victoria
# 4     2016-09-16  Unprovoked  Australia           Victoria
# ...          ...         ...        ...                ...
# 5096  1738-04-06  Unprovoked      Italy             Sicily
# 5097  1721-06-01  Unprovoked      Italy           Sardinia
# 5098  1703-03-26  Unprovoked   Barbados    Southwest coast
# 5099  1700-01-01  Unprovoked     France       Côte d'Azur
# 5100  1700-01-01  Unprovoked   Barbados  St Michael Parish
#
#                               Location Activity_during_attack  \
# 0     New Smyrna Beach, Volusia County                Surfing
# 1     New Smyrna Beach, Volusia County                Surfing
# 2     New Smyrna Beach, Volusia County                Surfing
# 3                     Thirteenth Beach                Surfing
# 4                          Bells Beach                Surfing
# ...                                ...                    ...
# 5096                 Strait of Messina               Swimming
# 5097            Ponte della Maddelena,               Swimming
# 5098                      Carlisle Bay               Swimming
# 5099                           Antibes                Bathing
# 5100                        Bridgetown                Bathing
#
#                                             Victim_Name Gender  Age  \
# 0                                                  male      M   16
# 1                                                  male      M   43
# 2                                        Chucky Luciano      M   36
# 3                                       Rory Angiolella      M   17
# 4                                                  male      M   17
# ...                                                 ...    ...  ...
# 5096                                               male      M   16
# 5097                                               male      M   16
# 5098  Samuel Jennings, a deserter from the British f...      M   19
# 5099                                             seaman      M   17
# 5100                               seaman from the York      M   17
#
#                                                  Injury  Fatal_attack  \
# 0                                 Minor injury to thigh         False
# 1                              Lacerations to lower leg         False
# 2                                  Lacerations to hands         False
# 3                          Struck by fin on chest & leg         False
# 4                 No injury: Knocked off board by shark         False
# ...                                                 ...           ...
# 5096                                              FATAL          True
# 5097  FATAL,  partial remains recovered from sharks...          True
# 5098  Hand and foot severely bitten, surgically ampu...         False
# 5099                                        Leg severed         False
# 5100                                              FATAL          True
#
#                      Shark_species                      Source_information  \
# 0                     Unidentified             Orlando Sentinel, 9/19/2016
# 1                     Unidentified             Orlando Sentinel, 9/19/2016
# 2                     Unidentified             Orlando Sentinel, 9/19/2016
# 3                     Unidentified                      The Age, 9/18/2016
# 4                        2 m shark                      The Age, 9/16/2016
# ...                            ...                                     ...
# 5096                  Unidentified                          C. Moore, GSAF
# 5097  White shark, 1600-lb female          F. Ricciardi; A. De Maddalena.
# 5098                  Unidentified                W.R.Cutter, Vol.1, p.252
# 5099                   White shark  A. De Maddalena, citing Cazeils (1998)
# 5100                  Unidentified                Tioga Eagle, 10.26/ 1842
#
#               Documentation_pdf  \
# 0          2016.09.18.c-NSB.pdf
# 1          2016.09.18.a-NSB.pdf
# 2      2016.09.18.b-Luciano.pdf
# 3     2016.09.17-Angiolella.pdf
# 4     2016.09.16-BellsBeach.pdf
# ...                         ...
# 5096   1738.04.06.R-Messina.pdf
# 5097   1721.06.00-Maddalena.pdf
# 5098    1703.03.26-Jennings.pdf
# 5099   1700.00.00.b-Antibes.pdf
# 5100  1700.00.00.a-Barbados.pdf
#
#                                      Documentation_href
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5096  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5097  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5098  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5099  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5100  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [5101 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5101 entries, 0 to 5806
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    5101 non-null   object
#  1   Type                    5101 non-null   object
#  2   Country                 5101 non-null   object
#  3   Area                    5101 non-null   object
#  4   Location                5101 non-null   object
#  5   Activity_during_attack  5101 non-null   object
#  6   Victim_Name             5101 non-null   object
#  7   Gender                  5101 non-null   object
#  8   Age                     5101 non-null   int64
#  9   Injury                  5101 non-null   object
#  10  Fatal_attack            5101 non-null   bool
#  11  Shark_species           5101 non-null   object
#  12  Source_information      5101 non-null   object
#  13  Documentation_pdf       5101 non-null   object
#  14  Documentation_href      5101 non-null   object
# dtypes: bool(1), int64(1), object(13)
# memory usage: 731.8+ KB

# %%
# saving data to csv file
data.to_csv("./Shark_attacks_cleaned.csv", index= False)
